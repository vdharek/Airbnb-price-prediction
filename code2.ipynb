# %%
import sys
# !{sys.executable} -m pip install geopandas
# !{sys.executable} -m pip install mplleaflet
# !{sys.executable} -m pip install bs4
# !{sys.executable} -m pip install geocoder
# !{sys.executable} -m pip install geopy
# !{sys.executable} -m pip install folium
# !{sys.executable} -m pip install lxml
# !{sys.executable} -m pip install pygeoj
# !{sys.executable} -m pip install pyshp
# !{sys.executable} -m pip install datetime
# !{sys.executable} -m pip install seaborn
# !{sys.executable} -m pip install --upgrade cython

# required package for timeseries
# !{sys.executable} -m pip install statsmodels

# requiered package to run geopandas
# !conda install -c conda-forge libspatialindex -y

# required packages for neighbourhood analysis
# !{sys.executable} -m pip install geopandas
# !{sys.executable} -m pip install descartes
# !{sys.executable} -m pip install requests

# requiered packages for accessibility analysis
# Make sure Cython is upgraded FIRST!
# !{sys.executable} -m pip install pandana

# requiered packages for modelling
# !{sys.executable} -m pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /home/vdharek/.local/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (1.3.5)
# Requirement already satisfied: fiona>=1.8 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: shapely>=1.6 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pyproj>=2.2.0 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: click>=4.0 in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (7.0)
# Requirement already satisfied: six>=1.7 in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (1.14.0)
# Requirement already satisfied: cligj>=0.5 in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (45.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=17 in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (2019.11.28)
# Requirement already satisfied: munch in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.25.0->geopandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/vdharek/.local/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/vdharek/.local/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.21.5)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mplleaflet in /home/vdharek/.local/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: jinja2 in /home/vdharek/.local/lib/python3.8/site-packages (from mplleaflet) (3.0.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from mplleaflet) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vdharek/.local/lib/python3.8/site-packages (from jinja2->mplleaflet) (2.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in /home/vdharek/.local/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/lib/python3/dist-packages (from bs4) (4.8.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geocoder in /home/vdharek/.local/lib/python3.8/site-packages (1.38.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from geocoder) (7.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from geocoder) (1.14.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from geocoder) (2.22.0)
# Requirement already satisfied: future in /home/vdharek/.local/lib/python3.8/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: ratelim in /home/vdharek/.local/lib/python3.8/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: decorator in /home/vdharek/.local/lib/python3.8/site-packages (from ratelim->geocoder) (5.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopy in /home/vdharek/.local/lib/python3.8/site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/vdharek/.local/lib/python3.8/site-packages (from geopy) (1.52)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /home/vdharek/.local/lib/python3.8/site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in /home/vdharek/.local/lib/python3.8/site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.3.0 in /home/vdharek/.local/lib/python3.8/site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in /home/vdharek/.local/lib/python3.8/site-packages (from folium) (3.0.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vdharek/.local/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in /usr/lib/python3/dist-packages (4.5.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pygeoj in /home/vdharek/.local/lib/python3.8/site-packages (1.0.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyshp in /home/vdharek/.local/lib/python3.8/site-packages (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datetime in /home/vdharek/.local/lib/python3.8/site-packages (4.3)
# Requirement already satisfied: pytz in /usr/lib/python3/dist-packages (from datetime) (2019.3)
# Requirement already satisfied: zope.interface in /home/vdharek/.local/lib/python3.8/site-packages (from datetime) (5.4.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from zope.interface->datetime) (45.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/vdharek/.local/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /home/vdharek/.local/lib/python3.8/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: scipy>=1.0 in /home/vdharek/.local/lib/python3.8/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /home/vdharek/.local/lib/python3.8/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy>=1.15 in /home/vdharek/.local/lib/python3.8/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=2.2->seaborn) (7.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib>=2.2->seaborn) (2.4.6)
# Requirement already satisfied: cycler>=0.10 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib>=2.2->seaborn) (20.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.23->seaborn) (2019.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.14.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cython in /home/vdharek/.local/lib/python3.8/site-packages (0.29.26)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in /home/vdharek/.local/lib/python3.8/site-packages (0.13.1)
# Requirement already satisfied: scipy>=1.3 in /home/vdharek/.local/lib/python3.8/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/vdharek/.local/lib/python3.8/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: numpy>=1.17 in /home/vdharek/.local/lib/python3.8/site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: pandas>=0.25 in /home/vdharek/.local/lib/python3.8/site-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/vdharek/.local/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.25->statsmodels) (2019.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.2->statsmodels) (1.14.0)
# /bin/bash: conda: command not found
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /home/vdharek/.local/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: pyproj>=2.2.0 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: shapely>=1.6 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pandas>=0.25.0 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (1.3.5)
# Requirement already satisfied: fiona>=1.8 in /home/vdharek/.local/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (45.2.0)
# Requirement already satisfied: six>=1.7 in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (1.14.0)
# Requirement already satisfied: munch in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=17 in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /home/vdharek/.local/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (2019.11.28)
# Requirement already satisfied: click>=4.0 in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (7.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/vdharek/.local/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/vdharek/.local/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.25.0->geopandas) (2019.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: descartes in /home/vdharek/.local/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: matplotlib in /home/vdharek/.local/lib/python3.8/site-packages (from descartes) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib->descartes) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib->descartes) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vdharek/.local/lib/python3.8/site-packages (from matplotlib->descartes) (4.28.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib->descartes) (20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->descartes) (2.4.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->descartes) (7.0.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.14.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (2.22.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandana in /home/vdharek/.local/lib/python3.8/site-packages (0.6.1)
# Requirement already satisfied: scikit-learn>=0.18 in /home/vdharek/.local/lib/python3.8/site-packages (from pandana) (1.0.2)
# Requirement already satisfied: numpy>=1.8 in /home/vdharek/.local/lib/python3.8/site-packages (from pandana) (1.21.5)
# Requirement already satisfied: cython>=0.25.2 in /home/vdharek/.local/lib/python3.8/site-packages (from pandana) (0.29.26)
# Requirement already satisfied: tables<3.7,>=3.1 in /home/vdharek/.local/lib/python3.8/site-packages (from pandana) (3.6.1)
# Requirement already satisfied: pandas>=0.17 in /home/vdharek/.local/lib/python3.8/site-packages (from pandana) (1.3.5)
# Requirement already satisfied: requests>=2.0 in /usr/lib/python3/dist-packages (from pandana) (2.22.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.17->pandana) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/vdharek/.local/lib/python3.8/site-packages (from pandas>=0.17->pandana) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in /home/vdharek/.local/lib/python3.8/site-packages (from scikit-learn>=0.18->pandana) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/vdharek/.local/lib/python3.8/site-packages (from scikit-learn>=0.18->pandana) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/vdharek/.local/lib/python3.8/site-packages (from scikit-learn>=0.18->pandana) (1.7.3)
# Requirement already satisfied: numexpr>=2.6.2 in /home/vdharek/.local/lib/python3.8/site-packages (from tables<3.7,>=3.1->pandana) (2.8.1)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from numexpr>=2.6.2->tables<3.7,>=3.1->pandana) (20.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17->pandana) (1.14.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /home/vdharek/.local/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: scipy in /home/vdharek/.local/lib/python3.8/site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in /home/vdharek/.local/lib/python3.8/site-packages (from xgboost) (1.21.5)

# %%
# %matplotlib inline

# general
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Geographical analysis
import geopandas as gpf #libspatialindex nees to be installed first
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import shapefile as shp
import datetime
from statsmodels.tsa.seasonal import seasonal_decompose
import requests
import descartes

# accessibility analysis
import time
from pandana.loaders import osm
from pandana.loaders import pandash5

# modelling
from sklearn.preprocessing import StandardScaler, MinMaxScaler 
from sklearn.model_selection import train_test_split, cross_val_score 
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn import metrics
import xgboost as xgb
from xgboost import plot_importance
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score

#Hide warnings
import warnings
warnings.filterwarnings('ignore')

# Set plot preference
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

print('Libraries imported.')
# Out:
# Libraries imported.
